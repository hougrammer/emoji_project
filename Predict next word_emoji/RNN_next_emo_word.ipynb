# %%
import tensorflow as tf
import tweet_reader
# import the inspect_checkpoint library
from tensorflow.python.tools import inspect_checkpoint as chkp
chck_dir = './checkpoints/'
# Out:
# /home/sm_ferro54/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
with tf.Session() as sess:
    tf.contrib.rnn
    new_saver = tf.train.import_meta_graph(chck_dir+'model.ckpt-5.meta')
    new_saver.restore(sess, tf.train.latest_checkpoint(chck_dir))
    print(sess.run('logits'))
# Out:
# WARNING:tensorflow:From /home/sm_ferro54/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/queue_runner_impl.py:391: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Restoring parameters from ./checkpoints/model.ckpt-10
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __init__(self, fetches, contraction_fn)
#     299         self._unique_fetches.append(ops.get_default_graph().as_graph_element(
# --> 300             fetch, allow_tensor=True, allow_operation=True))
#     301       except TypeError as e:
#
# ...

# %%
predictions = []
toy_example = ['feet', 'have', 'got', 'no', 'rhythm']
l = sess.run(logits,feed_dict={input_.input_data:toy_example})

# %%
acc_data = tweet_reader._read_words('test.csv')

# %%
len(acc_data)
# Out:
# 15858

# %%
chkp.print_tensors_in_checkpoint_file(chck_dir+'model.ckpt-5', tensor_name='', all_tensors=True)
# Out:
# tensor_name:  Model/Model/lstm_fused_cell/bias/Adam
# [-0.00164166  0.00205267 -0.00073235 -0.00324708  0.00421849  0.00167053
#  -0.0022493  -0.00014188]
# tensor_name:  Model/Model/lstm_fused_cell/bias/Adam_1
# [2.0285675e-07 1.1267088e-06 1.7818262e-06 1.1346772e-06 8.9758771e-07
#  4.6995132e-07 4.6609679e-07 1.6433621e-08]
# tensor_name:  Model/Model/lstm_fused_cell/kernel/Adam
# [[ 1.0512057e-03  2.8595836e-03 -4.9709331e-04 ...  1.5783355e-03
#    2.3152164e-04  1.0899300e-04]
#  [ 6.7154330e-04  1.7569580e-03  2.1174042e-04 ... -1.2137889e-03
#    1.9666650e-04 -9.5329597e-05]
#  [-8.8198605e-04 -2.1452038e-03 -2.3127499e-04 ... -1.8311471e-03
#    2.1673935e-05 -3.6410031e-05]
#  ...
#  [ 5.2954030e-04 -2.3065933e-03  2.3552493e-04 ... -1.4985432e-03
#   -2.4884102e-05 -9.8792276e-05]
#  [ 4.7856636e-04 -2.1821663e-03  4.8995798e-04 ... -1.2006818e-03
#    5.8442430e-04 -6.5918415e-05]
#  [-7.3199003e-04  3.9885257e-05  9.4759068e-04 ...  3.5337472e-04
# ...
